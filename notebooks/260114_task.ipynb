# %% [markdown]
# 안녕하세요. 수강생 여러분~! Chapter42 ~ 47 수업은 잘 들으셨나요?
#
# Chapter42 ~ 47의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
#
# <br>
#
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>

# %% [markdown]
# ---

# %% [markdown]
# [문제 1]
#
# 'Person'이라는 클래스를 선언하세요. 이 클래스는 name (이름)과 age (나이) 두 개의 속성을 갖습니다.<br>
#
# 그리고 'greet'라는 메소드를 갖고 있으며, 이 메소드는 "안녕하세요, 제 이름은 [name]입니다.
#
# 나이는 [age]살입니다."라는 메시지를 반환합니다.<br>
# 이 클래스를 사용하여 '홍길동'이라는 이름과 20살의 나이를 가진 'Person' 객체를 생성하고, 'greet' 메소드를 호출하여 메시지를 출력하세요.

# %%
class Person:
    def __init__(self, name: str, age: int) -> None:
        if not name or not age:
            raise ValueError ("이름 또는 나이 정보가 없습니다.")
        self.name = name
        self.age = age

    def greet(self):
        print(f"안녕하세요, 제 이름은 {self.name} 입니다. 나이는 {self.age}살 입니다.")

person = Person("홍길동", 20)
person.greet()
# Out:
# 안녕하세요, 제 이름은 홍길동 입니다. 나이는 20살 입니다.

# %% [markdown]
# ---

# %% [markdown]
# [문제 2]
#
# 'Rectangle' 클래스를 작성하세요.
#
# 이 클래스는 높이(height)와 너비(width)를 속성으로 가지며, 생성자(__init__)를 통해 이 두 속성을 초기화합니다.
#
# 'area' 메소드를 추가하여 사각형의 면적을 계산하고 반환하도록 하세요. 높이가 10, 너비가 5인 사각형 객체를 생성하고,<br>
# 이 객체를 사용하여 면적을 계산해 출력하세요.

# %%
class Rectangle:
    def __init__(self, height: float, width: float) -> None:
        self.height = height
        self.width = width

    def area(self):    
        print(f"사각형의 면적은 {self.height * self.width} 입니다.")

area_rectangle = Rectangle(10, 5)
area_rectangle.area()
# Out:
# 삼각형의 면적은 50 입니다.

# %% [markdown]
# ---

# %% [markdown]
# [문제 3]
#
# 'Book' 클래스를 선언하세요.
#
# 이 클래스는 title (제목)과 author (저자) 두 개의 속성을 갖습니다.
#
# __str__ 특수 메소드를 오버라이드하여, 객체를 문자열로 변환할 때 "제목: [title], 저자: [author]" 형식의 문자열을 반환하도록 하세요.
#
# 'Book' 객체를 하나 생성하고, print 함수를 사용하여 해당 객체의 문자열 표현을 출력하세요.

# %%
class Book:
    def __init__(self, title: str, author: str) -> None:
        self.title = title
        self.author = author

    def __str__(self):
        return f"제목: {self.title}, 저자: {self.author}" 

book = Book('개미', '베르나르베르베르')
print(book)
# Out:
# 제목: 개미, 저자: 베르나르베르베르

# %% [markdown]
# ---

# %% [markdown]
# [문제 4]
#
# 'Employee' 클래스를 선언하세요.
#
# 이 클래스는 월급인상률을 의미하는 클래스 변수로 'raise_amount'를 갖고 있으며, 기본값은 1.04입니다. 다음 급여는 기본 급여에 월급인상률을 곱한 값으로 결정합니다.
#
# 또한, 각 직원의 이름(name)과 급여(salary)를 속성으로 가지며, 'apply_raise' 메소드를 통해 급여에 'raise_amount'를 적용할 수 있어야 합니다.
#
# 'Employee' 클래스의 객체 두 개를 생성하고, 한 객체에만 'raise_amount'를 변경한 후, 두 객체의 급여를 증가시켜보세요.<br>
# 그리고 각 객체의 새로운 급여를 출력하세요.

# %%
class Employee:
    raise_amount = 1.04
    def __init__(self, name: str, salary: int) -> None:
        self.name = name
        self.salary = salary

    def apply_raise(self):
        self.salary = int(self.salary * self.raise_amount)


employee1 = Employee("김철수", 1000000)
employee2 = Employee("이영희", 1000000)

employee2.raise_amount = 1.20

employee1.apply_raise()
employee2.apply_raise()

print(f"{employee1.name}: {employee1.salary} ")
print(f"{employee2.name}: {employee2.salary} ")
# Out:
# 김철수: 1040000
# 이영희: 1200000

# %% [markdown]
# ---

# %% [markdown]
# [문제 5]
#
# 'Account' 클래스를 작성하세요.
#
# 이 클래스는 소유자(owner)와 잔액(balance)을 속성으로 가지며, 잔액은 프라이빗 변수로 선언합니다.
#
# 'deposit'와 'withdraw' 두 개의 메소드를 통해 잔액을 조작할 수 있도록 하세요.
#
# 이 때, 잔액은 음수가 될 수 없도록 체크해야 합니다. 'Account' 객체를 생성하고,<br>
# 입금 및 출금 작업을 시뮬레이션한 후, 최종 잔액을 출력하세요.

# %%
class Account:
    def __init__(self, owner: str, balance: int = 0) -> None:
        self.owner = owner
        self.__balance = balance  # 프라이빗 변수 (double underscore)
    
    def deposit(self, amount: int) -> None:
        """입금 메소드"""
        if amount <= 0:
            raise ValueError("입금액은 0보다 커야 합니다.")
        self.__balance += amount
        print(f"{amount}원이 입금되었습니다. 현재 잔액: {self.__balance}원")
    
    def withdraw(self, amount: int) -> None:
        """출금 메소드 - 잔액이 음수가 되지 않도록 체크"""
        if amount <= 0:
            raise ValueError("출금액은 0보다 커야 합니다.")
        if self.__balance < amount:
            raise ValueError(f"잔액이 부족합니다. 현재 잔액: {self.__balance}원")
        self.__balance -= amount
        print(f"{amount}원이 출금되었습니다. 현재 잔액: {self.__balance}원")
    
    def get_balance(self) -> int:
        """잔액 조회 메소드"""
        return self.__balance

# Account 객체 생성
account = Account("김철수", 1000000)

# 입금 및 출금 작업 시뮬레이션
account.deposit(50000)
account.withdraw(300000)
account.deposit(200000)
account.withdraw(1500000)  # 잔액 부족 시도 (에러 발생)

# 최종 잔액 출력
print(f"\n{account.owner}님의 최종 잔액: {account.get_balance()}원")
# Out:
# 50000원이 입금되었습니다. 현재 잔액: 1050000원
# 300000원이 출금되었습니다. 현재 잔액: 750000원
# 200000원이 입금되었습니다. 현재 잔액: 950000원
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 33
#      31 account.withdraw(300000)
#      32 account.deposit(200000)
# ---> 33 account.withdraw(1500000)  # 잔액 부족 시도 (에러 발생)
#      35 # 최종 잔액 출력
#      36 print(f"\n{account.owner}님의 최종 잔액: {account.get_balance()}원")
#
# Cell In[10], line 18, in Account.withdraw(self, amount)
#      16     raise ValueError("출금액은 0보다 커야 합니다.")
#      17 if self.__balance < amount:
# ---> 18     raise ValueError(f"잔액이 부족합니다. 현재 잔액: {self.__balance}원")
#      19 self.__balance -= amount
#      20 print(f"{amount}원이 출금되었습니다. 현재 잔액: {self.__balance}원")
#
# ValueError: 잔액이 부족합니다. 현재 잔액: 950000원

# %% [markdown]
# ---

# %% [markdown]
# [문제 6]
#
# 'Vehicle'이라는 기본 클래스를 선언하세요.
#
# 이 클래스는 make (제조사)와 model (모델명) 두 개의 속성을 갖고, 생성자(__init__)를 통해 이 두 속성을 초기화합니다. 'display_info'라는 메소드를 추가하여, "이 차량은 [make]에서 제조한 [model]입니다."라는 메시지를 반환하도록 하세요.
#
# 'Truck'과 'Car' 두 개의 하위 클래스를 생성하고, 각 클래스는 'Vehicle' 클래스로부터 상속받습니다.
#
# 'Truck' 클래스에는 추가로 'payload' (적재량) 속성을, 'Car' 클래스에는 'seats' (좌석 수) 속성을 추가합니다. 각각의 하위 클래스에서 'display_info' 메소드는 기본 클래스의 메소드를 그대로 사용합니다.
#
# 'Truck'과 'Car' 객체 각각을 생성하고, 'display_info' 메소드를 호출하여 정보를 출력하세요.
#
# 또한, 각 객체의 추가 속성(적재량, 좌석 수)에 대한 정보도 출력하세요.
#
# 이 문제는 클래스의 상속 개념을 이해하고, 기본 클래스의 속성과 메소드를 하위 클래스가 어떻게 활용할 수 있는지 보여줍니다.
#
# 오버라이드는 필요하지 않으며, 각 하위 클래스의 고유한 속성을 추가하는 방법에 초점을 맞춥니다.

# %%
class Vehicle:
    
    def __init__(self, make: str, model: str) -> None:
        self.make = make  
        self.model = model  
    
    def display_info(self) -> str:
        """차량 정보를 조회 메소드"""
        return f"이 차량은 {self.make}에서 제조한 {self.model}입니다."


class Truck(Vehicle):
    
    def __init__(self, make: str, model: str, payload: int) -> None:
        super().__init__(make, model)  
        self.payload = payload  


class Car(Vehicle):
    
    def __init__(self, make: str, model: str, seats: int) -> None:
        super().__init__(make, model)  
        self.seats = seats  


truck = Truck("현대", "포터", 5)
print(truck.display_info())
print(f"적재량: {truck.payload}톤\n")

# Car 객체 생성
car = Car("기아", "K5", 5)
print(car.display_info())
print(f"좌석 수: {car.seats}개")
# Out:
# 이 차량은 현대에서 제조한 포터입니다.
# 적재량: 5톤
#
# 이 차량은 기아에서 제조한 K5입니다.
# 좌석 수: 5개

# %% [markdown]
# ---
